# %% [markdown]
# ##Cabeçalho Principal:
#
# <p>["Larissa Moura", 20160000820]</p>
# <p>["Jonas Rocha", 2016037589]</p>
# <p>["Natalia Azevedo", 2015033469 ]</p>
# <p>[Michel Jean ,20170072190  ]</p>

# %% [markdown]
# ## Previsão (em minutos) para a conclusão do projeto:
# 60 a 90 minutos

# %% [markdown]
# # Joãozinho e sua jornada emocional
#
# Recentemente, Joãozinho terminou seu relacionamento, e agora está muito mal, na bad, na **sofrência**. Ele agora está tentando ouvir musicas sobre amor para viver intensamente a seu sofrimento pela pessoa amada. Ajude-o a recuperar os pedaços do seu **coração** que foram **dilacerados** por um outro alguém, através de músicas.
#
# __[Python]__
#
# Pandas é um pacote que fornece estruturas de dados rápidas, flexíveis e expressivas, projetadas para fazer com que trabalhar com dados "relacionais" ou "etiquetados" seja fácil  e intuitivo. É open-source e amplamente utilizado como ferramenta para análise de dados.
#
# Neste curso, utilizaremos o Pandas para ajudar Joãozinho em sua jornada emocional em busca de músicas que o ajudem a superar um termino de relacionamento.
#
# __[Dataframe]__
#
# Utilizaremos dois arquivos de datasets:
#
# - "66milsongs.csv":  Dataset que contém músicas de determinados artistas.
#   - [unnamed]: index que indica as rows do dataset;
#   - [song]: nome da música;
#   - [year]: ano de lançamento da música;
#   - [artist]: artista que lançou a música;
#   - [genre]: gênero da música;
#   - [lyrics]: letra completa da música;
#
# - "mood_words.csv": Dataset que lista palavras negativas e positivas de acordo com as "sentimenal words", referência proveniente do artigo "Mining and Summarizing Customer Reviews" dos autores Minqing Hu and Bing Liu.
#   - [positive_words]: palavras consideradas positivas;
#   - [negative_words]: palavras consideradas negativas;
#
#
# __[mathplots]__
#
# Neste projeto utilizaremos mathplots, para exibição de gráficos do tipo pizza (plt.pie()) e do tipo histograma(plt.hist()), explicaremos detalhadamente ao decorrer do curso.

# %% [markdown]
# ## Exercício 1 (Fácil)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Para começar, Joãozinho precisa carregar seu dataset para poder manipulá-lo.
# - use a função **read_csv()** do pandas para ler o dataset "66milsongs.csv" e guardar o DataFrame gerado na variável **data**. Atente para os separadores e o tipo de codificação que está sendo utilizado no arquivo;
#   - Dica: ";"
#   - Dica: "latin-1"
# - verifique seu DataFrame: utilize os métodos **info()**, **head()** e **shape()** para ter idéia de como ele está organizado.

# %%
# Uploading files from your local file system

from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
#put your code here.

# %% [markdown]
# ## Exercício 2 (Fácil)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Joãozinho quer saber que músicas são menores (mais fáceis de decorar).
# Acrescente ao DataFrame uma coluna com a quantidade de palavras de cada música.
# - Utilize o conteúdo da coluna __"lyrics"__ para determinar quantas palavras existem em cada música;
# - Acrescente o resultado à coluna __"number_of_words"__.
#
# Obs.: Lembre-se que a coluna __"lyrics"__ não esta tratada e pode possuir elementos com "\n" e espaços em branco.

# %%
#put your code here.

# %% [markdown]
# ## Exercício 3 (Fácil)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Joãozinho quer saber que músicas falam de amor (para desfrutar inteiramente da sua sofrência).
# Acrescente ao DataFrame uma coluna que diga se a música daquela linha tem a palavra "in love".
# - Utilize o conteúdo da coluna __"lyrics"__ para determinar se a música possue a palavra procurada;
# - Acrescente o resultado (True ou False) à coluna __"has_word_in_love"__.
# - Crie um Dataframe somente com as músicas de sofrência para que sirva de playlist para Joãozinho.

# %%
sofrencia_word = "in love"
#put your code here.

# %% [markdown]
# ## Exercício4  (Médio)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Curioso e com dor de cotovelo, Joãozinho quer saber qual a década que foram lançadas a maioria das músicas de sofrência.
#
# - Faça um histograma com a coluna **"year"** do dataframa **data** e descreva uma análise sobre qual a década que contém mais músicas de sofrência
#
# - Utilize as seguintes funções para plotar o gráfico:
#   - **plt.hist() #use como argumento a coluna "year"**
#   - **plt.title("titulo do histograma")**
#   - **plt.xlabel("nome do eixo x do gráfico")**
#   - **plt.ylabel("nome do eixo y do gráfico")**
#   - **plt.show()  "exibe o gráfico" **

# %% [markdown]
# [**Matplotlib]** <p>O Matplotlib é uma biblioteca de plotagem 2D em Python que produz números de qualidade de publicação em uma variedade de formatos impressos e ambientes interativos entre plataformas.</p>

# %% [markdown]
# **[Numpy]** <p>O NumPy é o pacote básico da linguagem Python que permite trabalhar com arranjos, vetores e matrizes de N dimensões, de uma forma comparável e com uma sintaxe semelhante ao software proprietário Matlab, mas com muito mais eficiência, e com toda a expressividade da linguagem. Além disso a biblioteca Matplotlib utiliza os recursos do numpy para ficar mais eficiente.</p>

# %%
#importando bibliotecas
import matplotlib.pyplot as plt
import numpy as np

#put your code here

# %% [markdown]
# put your analysis here

# %% [markdown]
# ## Exercício 5 (Médio)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Joãozinho tem gostos peculiares, não gosta de todos os estilos musicais, mas não sabe quais são todos os gêneros presentes na tabela pois ela é muito extensa.
#
# - Ajude a Joãozinho a descobrir quais são os gêneros que a tabela possui;
# - Sabendo que Joãozinho prefere músicas Pop e não é fã de músicas atuais (acha modinha) ordene o Dataframe da sofrência somente com músicas Pop com anos de lançamento em ordem decrescente.

# %%
#put your code here.

# %% [markdown]
# ## Exercício 6 (Médio)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Joãozinho é muito curioso e resolveu saber quem é o artista com mais músicas presentes no dataset inserido no projeto.
#
# - Ajude Joãozinho a descobrir qual artista possui mais canções no dataset **data**.
# -  Atribua o nome do músico com mais canções a variável **most_present_singer**
# <p>Dica: "Counter"</p>

# %%
#put your code here.

# %% [markdown]
# ## Exercício 7 (Díficil)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Sabendo quem é o artista Joãozinho se mostrou curioso para saber qual o teor das músicas desse músico.
#
# A ideia que Joãozinho teve foi a de ver quais são as cinco palavras mais usadas nas músicas desse artista.
#
# - Crie um dataframe somente com as músicas do artista encontrado na questão anterior, chame de  **"most_present_artist_songs"**;
# - Adicione a esse Dataframe a coluna **"most_used_words"** com as cinco palavras mais usadas em cada música, esta coluna deve estar ao lado da coluna **lyrics**;
# - Analise os resultados encontrados.
#
# Dica: Existe uma função chamada **dt.insert(loc, column, value, allow_duplicates=False)**, esta função insere uma coluna no Dataframe em determinada posição.
# Seus parametros são:
#   - loc: int, que recebe o index da coluna a ser inserida;
#   - column: string, número "hashable object", que é o rótulo da coluna a ser inserida.
#   - value : int, Series, ou array, que recebe o conteúdo da coluna (rows).
#   - allow_duplicates : boolean, é opcional e informa se a coluna permite duplicação ou não.

# %%
#put your code here.

# %% [markdown]
# ## Exercício 8 (Muito díficil)
# <img width="250" alt = "Exercicio!" src="https://cdn.someecards.com/someecards/usercards/coding-time--9bf1e.png">
#
# Joãozinho percebeu que descobrir as cinco palavras mais usadas, na questão anterior, não foi muito útil para saber o teor das músicas do artista.
#
# Logo, Joãozinho resolveu usar o dataframe **"mood_words"** (contém uma coluna de palavras positivas e outra de palavras negativas) para ajudá-lo a descobrir os "moods" de cada canção do dataframe criado no exercício 7 (most_present_artist_songs).
#
# Joãozinho deseja separar essas canção em dataframes de acordo com os **"moods"**, para que possa ouvir músicas especificas para viver a "fossa" e a "superação".
#
# - Adicione ao dataset (most_present_artist_songs) um coluna chamada **mood** indicando o mood de cada música (positivo, negativo ou neutro):
#   - É positivo se a quantiadde de palavras positivas for maior que as negativas;
#   - É negativo se a quantidade de palavras negativas for maior que as positivas;
#   - É neutra se a quantidade de palavras positivas e negativas forem iguais.
#
# - Crie dois dataframes um de músicas positivas e outro de músias negativas, para que sirva de playlist para Joãozinho quando ele precisar;
#
# - Plote um grafíco em formato de pizza exibindo as porcentagens de músicas positivas, negativas e neutras do dataframe analisado.
#
# Dicas:
# - Ao ler o arquivo use a "," como separador desta vez.
# - A função insert (usada no exercício 7) ainda pode ser usada neste exercício;
# - Para criar um gráfico pizza você pode usar a biblioteca "matplotlib.pyplot" (já importada no exercício 4) e utilizar as seguintes funções:
#   - **plt.pie()**, utilize somente os atributos: **sizes** (**Lista** com os tamanhos de cada valor a ser exibido), **labels=labels** (os nomes dos valores a serem exibidos separados por ",". Ex.: "Positivo", "Negativo", "Neutro"), colors=colors (**Lista** com as cores de cada "pedaço" da pizza, ordenadamente), autopct='%1.1f%%' (formato da porcentagem exibida).
#   - **plt.axis('equal')**
#   - **plt.title('Moods of ' + most_present_singer + "'s songs")**
#   - **plt.show()**
# Mais dúvidas consultar o link [https://pythonspot.com/matplotlib-pie-chart/](https://pythonspot.com/matplotlib-pie-chart/)

# %%
# Uploading "mood_words.csv" from your local file system

from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
#put your code here.
